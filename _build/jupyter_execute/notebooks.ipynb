# %% [markdown]
# # Where has the duck been?

# %%
import pandas as pd
import pyproj

from bokeh.plotting import figure, show, output_notebook, ColumnDataSource
output_notebook()

occ = pd.read_csv('occ.csv',index_col=0)

psource = ColumnDataSource(pd.DataFrame(pyproj.transform(pyproj.Proj(init='epsg:4326'), pyproj.Proj(init='epsg:3857'), occ['lon'], occ['lat'])).transpose().rename(columns={0:'x',1:'y'}))



# range bounds supplied in web mercator coordinates
p = figure(x_range=(-2000000, 2000000), y_range=(100000, 700000),
           x_axis_type="mercator", y_axis_type="mercator")

p.add_tile("CartoDB Positron", retina=False)

p.scatter('x', 'y', source=psource, color='red', size=10)

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cd7318eb-8d92-4196-aeb2-c2610f99f1c9">Loading BokehJS ...</span>
#     </div>
# /opt/anaconda3/envs/aciar/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /opt/anaconda3/envs/aciar/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /tmp/ipykernel_1538644/2856681665.py:9: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   psource = ColumnDataSource(pd.DataFrame(pyproj.transform(pyproj.Proj(init='epsg:4326'), pyproj.Proj(init='epsg:3857'), occ['lon'], occ['lat'])).transpose().rename(columns={0:'x',1:'y'}))
#   <div id="b866e254-8adb-43da-ad52-ae2aea4f1fad" data-root-id="p1004" style="display: contents;"></div>

# %% [markdown]
# There is a lot more that you can do with outputs (such as including interactive outputs)
# with your book. For more information about this, see [the Jupyter Book documentation](https://jupyterbook.org)
